# %% [markdown]
# # Assignment 1
# -------
# ## Particulars
#
# This assignment is due Thursday March 7, 2019. The last commit at (or before) 23h59 on that date will be graded for credit.
#
# It must be turned in (committed) to your private repository on the course's github organization located at [github.com/mgt-416-2019](https://github.com/mgt-416-2019).
#
# __Commit early and commit often.__ Waiting until the due date to start figuring out git/github is a very bad idea. Indeed, this assignment has been planned to be a bit less intense than future ones in anticipation that each student will have to spend a bit of time and effort into (re)acquainting him/her self with git, github, python and jupyter notebooks.
#
# -------
# ## Types of Problems and Evaluation
#
# On this assignment there are two types of questions: <span style="color:red">Technical</span> and <span style="color:blue">Analytical</span>.
#
# The primary goal of a <span style="color:red">technical</span> question is to carry out the requested coding/computational analysis and output or visualize the result. In these problems the primary factors in evaluation are: does the code/analysis work; does it do what it is supposed to do; is it comprehensible (_i.e._ commented [always] and explained [in cases where code is very involved]).
#
# The primary goal of an <span style="color:blue">analytical</span> question is to answer a question about some network(s) or data, being certain to justifying your answer with a well thought out and well presented line of reasoning. In these problems the primary factors in evaluation are: is the answer well thought out and it well presented and intelligibile (students are strongly advised to make use of [markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) and [magics](http://ipython.readthedocs.io/en/stable/interactive/magics.html) _ex_. %%latex or $\latex$ in their answers).
#
# Each problem and question has associated with it a number of points that it will be graded out of. Please use the point values as a guide as to how much time/effort should be devoted to each question.
#
# -------
# ## Instructions
#
# Complete each of the problems found below to the best of your abilities. It is highly advisable that you at least attempt each problem/question.
#
# After the cell proposing each problem there is a markdown cell in which your marks for that problem will be recorded and a code cell in which your total mark for that problem will be stored. __Do not edit these cells.__
#
# Following the marking cells there is a series of cells you may use to complete each question. Feel free to add additional markdown and code cells as required.
#
# If you encounter any major issues, require clarification and/or you believe there is an error in a question or the data, do not hesitate to email me at: [orion.penner@epfl.ch](mailto:orion.penner@epfl.ch).

# %% [markdown]
# -------
# ## Imports
#
# The packages imported below are necessary for completing the assignment.
#
# If there are other packages you are used to using that you wish to import, please feel free to do so __provided__ the package is __fully installable through pip__. If you want clarification on this, please email me.

# %%
# Allows matplotlib figures inline
# %matplotlib inline
# Our standard network analysis module. Please use as nx so I may read code more easily.
import networkx as nx
# Our standard ploting module. Again, please use as plt.
import matplotlib.pyplot as plt

# %% [markdown]
# The next imports are some packages I used in completing the problems to improve aesthetics or efficiency.
#
# But in no way are they necessary for solving each problem and if you don't use them it will not affect your grade in anyway.

# %%
# numpy can be more efficient at getting sum, max, min, etc. out of arrays and lists.
import numpy as np
# Can be used to make the printing of certain objects (especially dictionaries and tuples) easier for humans.
import pprint
# Just a lazy way of supressing warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# All of these packages _should_ be standard in conda but if you encounter an issue in importing them first try using pip within the notebook. For example, to install matplotlib you could run (in a code cell) the following command: !pip install matplotlib

# %% [markdown]
# ----

# %%
# Initialize our list of problem scores
Scores = []

# %% [markdown]
# ----
# ## Problem 0
# 5 points.
#
# As I mentioned in class, there may be some free points for getting on top of git and github early. These are those points:
#
# 1. Fill out the questions in the cell below. [<span style="color:blue">Analytical</span>] [2]
# 2. Commit and push the notebook to your private repository before 21h00 of Tuesday March 5, 2019. [<span style="color:red">Technical</span>] [3]

# %% [markdown]
# __First Name__: Nicolas
#
# __Last Name__: Lesimple
#
# __SCIPER #__: 267699
#
# __Major__: Yes
#
# __Programming Experience__ (One or two sentences):  I did six months internship in a Machine Learning consulting company where my goal was to forecast time series. Moreover, since the beginning of my study at EPFL, I did a lot of courses in Programmation and now I'm in the master called Computational Science and Engineering. Thus I have some experience in the field.
#
# __Python Experience__ (One or two sentences): I did courses like Machine Learning and Applied Data Analysis at EPFL and as these courses are made with a huge project in python I have some experience in the field. Moreover, I coded in Python all day long for my 6-month internship.
#
# __Jupyter Notebook Experience__ (yes/no): yes
#
# __Operating System__: OS
#
# __What do you want to do after finishing your Master__ (One or two sentences): <br>
# For example, PhD or industry. Do you have a sector in mind. In Switzerland, within Europe, further abroad?
# I would like to work in the industry and more specifically I would love to work in a consulting company in Machine Learning. I would prefer to live in the French part of Switzerland as my family is settled in the region.

# %% [markdown]
# #### Problem 0 Marks
#
# 0.1) 2/2
#
# 0.2) 3/3
#
# Total: 5/5

# %%
Problem0Score = 5
Scores.append(Problem0Score)

# %% [markdown]
# ----
# ## Problem 1
#
# 5 points.
#
# In cloning your private repository (and by extension, this assignment) you will also have downloaded three network data files: network_1.txt, network_2.adj and network_3.gml. These networks will be the data we use throughout this assignment and we will start by inspecting them:
#
# 1. Inspect each file and indicate which network representation/format is being used. _hint_: also use the information in the file extension [<span style="color:blue">Analytical</span>] [2]
# 2. Load each network as a networkx graph object. Please name the graphs G_1, G_2 and G_3 respectively. They will be referred to using those labels in subsequent questions. Don't hesitate to use the [networkx documentation](https://networkx.github.io/documentation/stable/reference/index.html) [<span style="color:red">Technical</span>] [2]
# 3. Print (print()) a quick summary of each network's properties (N, L, _etc._ nothing too fancy). _hint_: you should recall there is a built in function in networkx for this [<span style="color:red">Technical</span>] [1]

# %% [markdown]
# #### Problem 1 Marks
#
# 1.1) 2/2
#
# 1.2) 2/2
#
# 1.3) 1/1
#
# Total: 5/5

# %%
Problem1Score = 5
Scores.append(Problem1Score)

# %% [markdown]
# ----

# %% [markdown]
# ### 1.1
# ***Inspect each file and indicate which network representation/format is being used. hint: also use the information in the file extension:***

# %% [markdown]
# As asked, we inspect each file and find the network representation. Using the hint, we can see that the file extension are different for each file. In fact, we have the following file names :
#
#
#    * network_1.txt: This file is a text file. The text is a human-readable sequence of characters and the words they form that can be encoded into computer-readable formats. Here is the format from the file : 1 48 {} 1 53 {} 1 54 {} 1 73 {}. Each line corresponds to an edge between 2 nodes. In fact, the first element means that an edge exists between the node 1 to the node 48. Thus, **the representation/format used is a Link List**.  We use the nx.read_edgelist command to read it.
#
#
#    * network_2.adj: This file is an adjacency list file. Thus **the representation/format used is a kind of Adjacency Matrix**. We use the nx.read_adjlist command to read it. Here is a example of the format for the first line : 1 48 53 54 73 88 92 119 126 133 194 236 280 299 315 322 346 45 323 44 35 203. It gives all the edge that has, as the source, the node 1 and has, as the target nodes, all the other node in the line.
#
#
#    * network_3.gml: This file is a .gml file. GML, the Graph Modelling Language, is a portable file format for graphs. GML’s key features are portability, simple syntax, extensibility, and flexibility. A GML file consists of a **hierarchical key-value lists**. Graphs can be annotated with arbitrary data structures. Here is the format found in the file : graph [ node[id 0 label 1] edge[source 4 target 157]]. The first structure indicates the id and the label of each node. The second one represents an edge and thus indicate which source node is linked to the target node. Thus, **the representation/format used is a kind of Link List**. We used the command nx.read_gml to load the file.

# %% [markdown]
# ### 1.2
# ***Load each network as a networkx graph object :***

# %%
# load the data and create a graph
G_1 = nx.read_edgelist('./network_1.txt', create_using=nx.Graph(), nodetype=int)
plt.figure(figsize=(14,7))
nx.draw_networkx(G_1, pos=nx.spring_layout(G_1), with_labels = False, node_size = 30)
plt.title('G_1 graph representation :')
plt.show()

# %%
# load the data and create a graph
G_2 = nx.read_adjlist('./network_2.adj', create_using=nx.Graph(), nodetype=int)
plt.figure(figsize=(14,7))
nx.draw_networkx(G_2, pos=nx.spring_layout(G_2), with_labels = False, node_size = 30)
plt.title('G_2 graph representation :')
plt.show()

# %%
# load the data and create a graph
G_3 = nx.read_gml('./network_3.gml')
plt.figure(figsize=(14,7))
nx.draw_networkx(G_3, pos=nx.spring_layout(G_3), with_labels = False, node_size = 30)
plt.title('G_3 graph representation :')
plt.show()

# %% [markdown]
# ### 1.3
# ***Print (print()) a quick summary of each network's properties :***

# %%
# print out the summary information of the graphs
print('G_1 Informations Summary: \n')
print(nx.info(G_1),'\n')
print('G_2 Informations Summary: \n')
print(nx.info(G_2),'\n')
print('G_3 Informations Summary: \n')
print(nx.info(G_3),'\n')
# Out:
# G_1 Informations Summary:
#
# Name:
# Type: Graph
# Number of nodes: 486
# Number of edges: 4037
# Average degree:  16.6132
#
# G_2 Informations Summary:
#
# Name:
# Type: Graph
# Number of nodes: 500
# Number of edges: 5219
# Average degree:  20.8760
#
# G_3 Informations Summary:
#
# Name:
# Type: Graph
# Number of nodes: 500
# Number of edges: 5219
# Average degree:  20.8760

# %% [markdown]
# Thanks to this information for each network, we can draw two conclusions :
#    * G_1 network is smaller than G_2 and G_3 network in term of number of nodes, number of edges and average degree.
#    * G_2 and G_3 network are exactly identical in term of number of nodes, number of edges and average degree. This observation seems strange but thus we check by looking inside raw data with our own eyes for the first node and indeed, G_2 and G_3 network are the same.

# %% [markdown]
# ----
# ## Problem 2
#
# 10 Points
#
# In the second lecture we discussed the _degree distribution_ of a network. In this problem you will explore the degree distributions of the three networks loaded in Problem 1.
#
# 1. Plot the degree distributions of the three networks. In doing so please:
#     * Present each degree distribution in both _linear-linear_ and _log-linear_(y-axis being log scaled) formats.
#     * Clearly and correctly label your axes.
#     * Present one distribution as pure counts (frequency) and the other two as probabilities. [<span style="color:red">Technical</span>] [3]
# 2. Briefly compare and contrast the degree distribution of each pair of networks (G_1-G_2, G_1-G_3, G_2-G_3). [<span style="color:blue">Analytical</span>] [2]
# 3. Focusing on G_1 and G_2, compare in greater depth using the criteria covered in Lecture 2 pages 84-92. [<span style="color:blue">Analytical</span>] [2]
# 4. If I told you that these networks were "friendship networks" drawn from three different schools, what do these degree distributions tell you about friendship patterns in these three schools. What kind of forces (for example, class size) could be in play at the two different schools that may explain the differences. Are there networks outside the school context itself that could also be effecting this network and its degree distribution. [<span style="color:blue">Analytical</span>] [3]
#
# Note: As you are producing many histograms in this problem and subsequent ones, below I provide a suitable function. You may feel free to create your own or alter mine as you see fit. But understand that on future assignment these kinds of functions will be provided less and less -- greater proficiency with packages and tools (especially matplotlib) will be required.

# %% [markdown]
# #### Problem 2 Marks
#
# 2.1) 3/3 - Consider more bins, would see a bit more structure.
#
# 2.2) 2/2
#
# 2.3) 2/2
#
# 2.4) 3/3
#
# Total: 10/10

# %%
Problem2Score = 10
Scores.append(Problem2Score)

# %% [markdown]
# ----

# %%
def nx_hist(x, bins, normed = False, yscale = 'linear', title = None, xlabel = 'Degree', ylabel = 'Count'):
    '''
    This function can be used for plotting histograms.
    ARGS: 
    - x: The input data (x) should be in the form of a list.
    - Each other input is just a variable determining some characteristic of the resulting plot : 
        - bins: Integer corresponding to the number of bins used in the histogram.
        - normed: Boolean indicating if we want to normalize the histogram.
        - yscale: String which should be 'linear' or 'log' indicating the scale of the y-axis.
        - title: String corresponding to the title of the histogram.
        - xlabel, ylabel: String corresponding to each axis.
    RETURN :
        - This function returns nothing but it plots the wanted histogram. None object is returned.
    NOTE : 
    As this is basically just a wrapper of the matplotlib hist function, its documentation can be consulted as well.    
    '''
    density = None
    if(normed):
        density = 1
        ylabel = 'Probability'
    plt.hist(x, bins=bins, normed=density)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.yscale(yscale)
    plt.title(title)
    plt.grid(True)
    plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### 2.1
#
# ***Plot the degree distributions of the three networks :***
#    * Present each degree distribution in both _linear-linear_ and _log-linear_(y-axis being log scaled) formats.
#    * Clearly and correctly label your axes.
#    * Present one distribution as pure counts (frequency) and the other two as probabilities.

# %%
def plot_question_2_1(yscale_input = 'linear'):
    '''
    This function allows the printing of all the elements needed to answer question 2.1.
    It prints 3 histograms (one for each graph) with the defined scale. G_1 y-axis is in frequency and G_2 and G_3 plot are probabilities.
    ARGS :
        - yscale_input: String which should be 'linear' or 'log' indicating the scale of the y-axis.
    RETURN :
        - This function returns nothing but it plots the wanted histogram. None object is returned.
    '''
    # Find all the degree of each graph
    degree_pairs_G_1 = list(G_1.degree())
    degree_G_1 = zip(*degree_pairs_G_1)
    degree_pairs_G_2 = list(G_2.degree())
    degree_G_2 = zip(*degree_pairs_G_2)
    degree_pairs_G_3 = list(G_3.degree())
    degree_G_3 = zip(*degree_pairs_G_3)

    # Plot the first graph in frequency in yscale_input scale
    #nx_hist(list(degree_G_1)[1], bins = 12, normed = False, yscale = yscale_input, title = f'Degree Distribution of the network G_1 with {yscale_input} scale', xlabel = 'Degree', ylabel = 'Count')
    nx_hist(list(degree_G_1)[1], bins = 12, normed = False, yscale = yscale_input, title = 'Degree Distribution of the network G_1 with {} scale'.format(yscale_input), xlabel = 'Degree', ylabel = 'Count')
    # Plot the second graph in probability in yscale_input scale
    #nx_hist(list(degree_G_2)[1], bins = 12, normed = True, yscale = yscale_input, title = f'Degree Distribution of the network G_2 with {yscale_input} scale', xlabel = 'Degree', ylabel = 'Probability')
    nx_hist(list(degree_G_2)[1], bins = 12, normed = True, yscale = yscale_input, title = 'Degree Distribution of the network G_1 with {} scale'.format(yscale_input), xlabel = 'Degree', ylabel = 'Probability')
    # Plot the third graph in probability in yscale_input scale
    #nx_hist(list(degree_G_3)[1], bins = 12, normed = True, yscale = yscale_input, title = f'Degree Distribution of the network G_3 with {yscale_input} scale', xlabel = 'Degree', ylabel = 'Probability')
    nx_hist(list(degree_G_3)[1], bins = 12, normed = True, yscale = yscale_input, title = 'Degree Distribution of the network G_1 with {} scale'.format(yscale_input), xlabel = 'Degree', ylabel = 'Probability')

# %%
# We answer the question 2.1 by plotting 6 hitograms
# We choose to present G_1 disctribution as pure counts (frequency) and the two other as probability
#print(f'Degree Distribution for each network using Linear-Linear Scale : \n') 
print('Degree Distribution for each network using Linear-Linear Scale : \n') 
plot_question_2_1(yscale_input = 'linear')
#print(f'Degree Distribution for each network using Log-Linear Scale (y-axis being log scaled): \n')
print('Degree Distribution for each network using Log-Linear Scale (y-axis being log scaled): \n')
plot_question_2_1(yscale_input = 'log')
# Out:
# Degree Distribution for each network using Linear-Linear Scale :
# Degree Distribution for each network using Log-Linear Scale (y-axis being log scaled):

# %% [markdown]
# ### 2.2
#
# ***Briefly compare and contrast the degree distribution of each pair of networks (G_1-G_2, G_1-G_3, G_2-G_3).***

# %% [markdown]
#    * ***Comparison G_1-G_2***: The two distributions are equivalent. It seems to have a decreasing exponential trend. The size of the right tail in both distributions is similar. There is a difference in the number of extreme values. The G_1 distribution has just a few values around the degree 150 compare to the G_2 distribution who have few values around degree 100 and between 140 degrees and 160 degrees. Thus G_2 distribution has more extreme values but this kind of extreme numbers stays low in both distribution. The distributions done with the log scale are illustrating these facts and allows us to see well the small difference in extreme values. **In conclusion, these two distributions are similar and have an exponential decay trend. In G_2 distribution there is a little bit more extreme values. **
#
#
#    * ***Comparison G_2-G_3***: G_2 and G_3 distribution seem to have exactly the same shape : degree distribution is identical. In fact, extreme values seem to be the same. We can see this on the distributions with a linear and logarithmic scale. **In conclusion, these two distributions seems to be identical, have an exponential decay trend and have the same extreme values.**
#
#
#    * ***Comparison G_1-G_3***: As we said previously, G_2 and G_3 distribution are identical. Thus the comparison between G_1-G_3 is the same as G_1-G_2. **Thus, these two distributions are similar, have an exponential decay trend and have difference in the number of extreme values.**

# %% [markdown]
# ### 2.3
# ***Focusing on G_1 and G_2, compare in greater depth using the criteria covered in Lecture 2 pages 84-92.***

# %% [markdown]
# **Information :**
#
# Here is the different property of the graph G_1 :
#    * Number of nodes: 486
#    * Number of edges: 4037
#    * Average degree:  16.6132
#
# Here is the different property of the graph G_2 :
#    * Number of nodes: 500
#    * Number of edges: 5219
#    * Average degree:  20.8760
#
# **First Conclusion draw thanks to previous information :**
#
# The first conclusion we can draw is that the average degree is similar, i.e in the same magnitude. The property for the two graphs are similar with more edges for the graph G_2. Thus, as the average degree is higher for G_2, the **distribution should be centered righter compare to G_1.** This is the case.
#
# **Right tail :**
#
#
# The main difference is the right tail :
#    * In the right tail of G_1, we can find one node which is connected to 150 other nodes, which correspond to 31% of the network. This node is **10 times more connected than an average node**.
#    * In the right tail of G_2, we can find few nodes which are connected to 140 between 160 other nodes, which correspond to approximately 30% of the network. These nodes are 7 to 8 times more connected than an average node. **In G_2 there is more nodes with extreme degree than in G_1 network.**
#
#
# **Distribution Peak:**
#
#
# For both distributions, the peak of the **distribution is centered at the origin**. This is not unusual. Thus, it generally implies nothing special.
#
# **Trend: Functional form of P(k) :**
#
#
# For both distributions, the trend seems to be an **exponential decay**. This fact is also underlined by the log scale histograms.
#
# **Significant Difference:**
#
#
# From all this analysis, it **seems that there is no significant difference** between the two distributions.

# %% [markdown]
# ### 2.4
# ***If I told you that these networks were "friendship networks" drawn from three different schools, what do these degree distributions tell you about friendship patterns in these three schools. What kind of forces (for example, class size) could be in play at the two different schools that may explain the differences. Are there networks outside the school context itself that could also be effecting this network and its degree distribution.***

# %% [markdown]
# **Recall of definition :**
#
# First, let's recall what is exactly the degree distribution to answer this question :
# The degree distribution (p(k)) of a network is the probability that a randomly selected node in the network has degree k. Hence this is a probability distribution.
# We also denote the cumulative as P(k), which is the fraction of nodes with degree less than k. For real-world networks, the degree distribution ultimately comes from the frequency (counts).
#
#
# **Meaning of distributions :**
#
# We make the hypothesis that these networks were "friendship networks" drawn from three different schools.
#
# The first things we can say is that based on the actual information, it's **impossible to say that network G_2 and G_3 are different**. Thus, we will consider that everything applies to G_2 is also true for G_3 are we consider them as identical.
#
# Moreover, as we said before, the **network G_1 and G_2 are similar**. They both have an exponential trend (also illustrating by log scale histogram) which means that the **probability for a node to have a low degree (<20) is extremely high**. In addition, the peak of the distribution is centered at the origin which also illustrates this fact. Thus we can conclude that in these two "friendship networks", it is **usual to know a small group of people** but not to know half of the school. This second concept corresponds to the extreme values of each distribution. This conclusion **make sense in reality as "friendship networks" apply in school are made with a small group that corresponds to all the person you are working with**. For example, you are usually connected to the people of your own class and not to the other guys of the entire school.
#
# **Forces in play that could explains the differences between G_1 and G_2 :**
#
# There are two main differences between this two degree distribution :
#    * The average degree is similar, i.e in the same magnitude but it's a little bit higher for G_2. Thus the G_2 distribution is centered righter compare to G_1. This means that you have a **higher probability to have less friend in G_1 school**. The force that could explain this fact can be **the class size**. In fact, perhaps in G_1 school, there are fewer students per class (for example 16) and in comparison, in G_2 school there are more students per class (for example 20). This class size characteristic could explain the average node degree difference as it makes sense that people in the same class have a higher chance to be connected.
#    * The right tails with some **extreme values**. In fact, in G_2, there are more nodes with an extreme degree than in G_1 network but the number of extreme values stays low. We can explain this observation with the fact that **some guys have role/work in the school that allows him to be in contact with much more people like for example the director or class representative**.
#
#
# **Are there networks outside the school context itself that could also be effecting this network and its degree distribution :**
#
# Imagine a network which is made with **"friendship networks" in like a sports club or other extra scholar activity**  friendship network. This type of network could totally affect our school network as people can go out of their circle of relations and thus meet new people and this external network can thus have influence and implies the creation of new edges for example.

# %% [markdown]
# ----
# ## Problem 3
# 13 points.
#
# In the second lecture we covered a couple of different ways to calculate clustering of a graph. This problem deals mostly with the individual, or node level, clustering coefficient:
#
# <center>$C_i = \frac{2L_i}{k_i(k_i-1)}$</center>
#
# where $i$ is the node you are calculating the clustering coefficient for, $L_i$ is the number of links between neighbours of $i$ and $k_i$ is the degree of $i$.
#
# For networks G_2 and G_3:
# 1. Calculate the clustering coefficient of each node. [<span style="color:red">Technical</span>] [1]
# 2. Calculate and report the average clustering coefficient. [<span style="color:red">Technical</span>] [1]
# 3. Plot the distribution of clustering coefficients - $p(C_i)$. _hint_: The nx_hist function provided previously does this just fine. [<span style="color:red">Technical</span>] [1]
# 4. Calculate the _overall_ clustering of each of the networks. _hint_: refer to the Lecture 2 slides to recall the difference between the overall clustering and the average clustering coefficient [<span style="color:red">Technical</span>] [1]
# 5. Calculate the density of each network. [<span style="color:red">Technical</span>] [1]
# 6. Place the results you got for average clustering coefficient, overall clustering and density, for each network, in a markdown table (template found below). Looking only at these summary statistics how do the networks differ? Considering these metrics, do you see any clear explanation for why they differ in that way? [<span style="color:blue">Analytical</span>] [1]
# 7. Looking at the distribution of clustering coefficients -$p(C_i)$- how do the networks differ. Considering these distributions do you see any clear explanation for why they differ? [<span style="color:blue">Analytical</span>] [2]
# 8. If I told you that both of these networks were based on data drawn from power grids in two different nations, compare and contrast the nations' strategy for power distribution on this level. [<span style="color:blue">Analytical</span>] [2]
# 9. If I told you that these networks were "friendship networks" drawn from two different schools, how do the patterns of friendship differ between the two schools? What kind of forces could be in play at the two different schools that may explain the differences. Feel free to think creatively, but also respect the bounds of logic. [<span style="color:blue">Analytical</span>] [3]
#
# _hint_: networkx has easy to use built in functions for calculating each of these quantities, although you must take care with Question 4.

# %% [markdown]
# #### Problem 3 Marks
#
# 3.1) 1/1
#
# 3.2) 1/1
#
# 3.3) 1/1 - Don't use log axis in these cases.
#
# 3.4) 1/1
#
# 3.5) 1/1
#
# 3.6) 1/1
#
# 3.7) 2/2
#
# 3.8) 2/2 - I don't really follow the small world point.
#
# 3.9) 3/3
#
# Total: 13/13

# %%
Problem3Score = 13
Scores.append(Problem3Score)

# %% [markdown]
# ----

# %% [markdown]
# #### In all this part we will just work on networks G_2 and G_3 :

# %% [markdown]
# ### 3.1
# ***Calculate the clustering coefficient of each node.***

# %%
# we used the build in function of networkx
cl_coefs_G_2 = nx.clustering(G_2)
cl_coefs_G_3 = nx.clustering(G_3)

# %% [markdown]
# ### 3.2
#
# ***Calculate and report the average clustering coefficient :***

# %%
# we can use the numpy function to calculate the mean
mean_cl_G_2 = np.mean(list(cl_coefs_G_2.values()))
mean_cl_G_3 = np.mean(list(cl_coefs_G_3.values()))
# or we can use the build in function of networkx
print('Mean Coefficient Clustering of G_2 with two different technics: \n  Matrix mean:', mean_cl_G_2, '\n  Built-in function :', nx.average_clustering(G_2))
print('Mean Coefficient Clustering of G_3 with two different technics: \n  Matrix mean:', mean_cl_G_3, '\n  Built-in function :', nx.average_clustering(G_3))
# The difference in the results (last numbers which are negligeable) comme from some approximation in float done during calculation
# Out:
# Mean Coefficient Clustering of G_2 with two different technics:
#   Matrix mean: 0.35255714478733013
#   Built-in function : 0.35255714478733013
# Mean Coefficient Clustering of G_3 with two different technics:
#   Matrix mean: 0.1916970912563346
#   Built-in function : 0.19169709125633477

# %% [markdown]
# ### 3.3
#
# ***Plot the distribution of clustering coefficients -  p(Ci)***

# %%
nx_hist(list(cl_coefs_G_2.values()), bins = 12, normed = False, yscale = 'linear', title = 'Clustering Coefficient Distribution of the network G_2 with linear scale', xlabel = 'Clustering Coefficient', ylabel = 'Count')
nx_hist(list(cl_coefs_G_3.values()), bins = 12, normed = False, yscale = 'linear', title = 'Clustering Coefficient Distribution of the network G_3 with linear scale', xlabel = 'Clustering Coefficient', ylabel = 'Count')
nx_hist(list(cl_coefs_G_2.values()), bins = 12, normed = False, yscale = 'log', title = 'Clustering Coefficient Distribution of the network G_2 with log scale', xlabel = 'Clustering Coefficient', ylabel = 'Count')
nx_hist(list(cl_coefs_G_3.values()), bins = 12, normed = False, yscale = 'log', title = 'Clustering Coefficient Distribution of the network G_3 with log scale', xlabel = 'Clustering Coefficient', ylabel = 'Count')

# %% [markdown]
# ### 3.4
#
# ***Calculate the overall clustering of each of the networks :***
#
# We know that transitivity can also be referred to as the overall clustering.

# %%
# find the overall clustering corresponding to find the transitivity of the network by using the build in networkx function
print('Overall Clustering Coefficient/Transitivity for G_2 : ', nx.transitivity(G_2))
print('Overall Clustering Coefficient/Transitivity for G_3 : ', nx.transitivity(G_3))
# Out:
# Overall Clustering Coefficient/Transitivity for G_2 :  0.3082826940119002
# Overall Clustering Coefficient/Transitivity for G_3 :  0.1837257880744398

# %% [markdown]
# ### 3.5
#
# ***Calculate the density of each network:***

# %%
# find the density of the network by using the build in networkx function
print('Density of the network G_2 : ', nx.density(G_2))
print('Density of the network G_3 : ', nx.density(G_3))
# Out:
# Density of the network G_2 :  0.04183567134268537
# Density of the network G_3 :  0.04183567134268537

# %% [markdown]
# ### 3.6

# %% [markdown]
# ***Place the results you got for average clustering coefficient, overall clustering and density, for each network, in a markdown table (template found below). Looking only at these summary statistics how do the networks differ? Considering these metrics, do you see any clear explanation for why they differ in that way?***
#
#
# |         | Overall clust | Average clust | Density  |
# |---------| :-----------: |:-------------:| :-------:|
# |Network 2|   0.308282    |     0.352557  | 0.04183  |
# |Network 3|   0.183725    |   0.191697    | 0.04183  |

# %% [markdown]
# **Density:**
#
# We can see that **the density is the same for both graphs**. In fact, from the basics information found at the beginning of the assignment, we can see that the two graphs have the same number of nodes and edges. In this point of view, they are identical.
#
# **Clustering Theory:**
#
# In graph theory, a clustering coefficient is a measure of the degree to which nodes in a graph tend to cluster together. Evidence suggests that in most real-world networks, and in particular social networks, nodes tend to create tightly knit groups characterized by a relatively high density of ties; this likelihood tends to be greater than the average probability of a tie randomly established between two nodes. The networks with the largest possible average clustering coefficient are found to have a modular structure, and at the same time, they have the smallest possible average distance among the different nodes.
#
# ***Overall clustering:*** The overall clustering or the transitivity is the ratio of all existing triangles over all possible triangles. It is the fraction of “triads” (two-link with a shared node) that are “closed” by a third link. **The overall clustering of the network 2 is higher compared to the network 3. The conclusion we can draw is that people in Network2 are more linked to each other and thus more clustered**.
#
# ***Average clustering:*** The average clustering is the mean of the clustering coefficient of each node where the clustering coefficient of a node is the fraction of a node’s neighbors that are also linked. **The average clustering of the network 2 is also higher compared to the network 3. The conclusion we can draw is that people in Network2 are more linked to each other and thus more clustered.**
#
# **Explanation of difference:**
#
# Networks differ in that way probably because of the network 3 in more homogenous. By that, I want to say that the **network 2 should be more structured/compartmentalized in several independent groups** compared to the network 3 which is more a global group, less make in small subparts.

# %% [markdown]
# ### 3.7

# %% [markdown]
# ***Looking at the distribution of clustering coefficients - p(Ci) - how do the networks differ. Considering these distributions do you see any clear explanation for why they differ?***
#
# **how do the networks differ :**
#
# Thanks to the distribution, we can see that more than 95% of the Clustering coefficient have values betweem 0 and 0.4 for network 3. In opposition, the network 2 has more than 95% of the Clustering coefficients betweem 0 and 0.8. Thus the distribution of the clustering coefficient of the network 3 is more tight (in term of range and distribution lenght) in comparison to the network 2.
# In fact, in theory, each distribution should be centered approximately near the average clustering coefficient which is 0.35 for network 2 and 0.19 for network 3 which is the case in our plots.
#
# In fact, we can say that the shape of the network 2 distribution is similar to the shape of a normal distribution centered in 0.35 with a sigma of 0.3. In comparion, the network 3 have the shape of a normal distribution centered in 0.2 with a sigma of 0.2.
#
# To conclude, **the distribution of clustering coefficients differs in term of center and in term of the range of data cover by the majority of the coefficient. In fact, the probability for a node of having a high clustering coeficient in higher for network 2 than for network 3.**
#
# **Explanation for why they differ :**
#
# The higher the clustering coefficient of a node is, the higher the fraction of a node’s neighbors are linked to the node of interest. One of the most prominent features of social networks is that networks tend to be highly clustered. That is, your friends, are also your friend’s friends. When viewed as a network, this phenomenon presents itself as a clique or complete graph. We can simply count the frequency of cliques within a graph to estimate how prevalent they are. Thus the higher the clustering coefficient is for a node, the higher the number of edges creating cycle next to will be. Thus they differ in this way because edges of network 2 are creating more clusters than network 3. **The network 2 is plenty of different clusters from different shape as the distribution shows. In opposition, the network 3 has also clusters but clusters that are less visible, i.e that is a less perfect cycle. Perhaps, some edges of network 2 succeed to link two clusters that would not be linked in network 3.**

# %% [markdown]
# ### 3.8
#
# ***If I told you that both of these networks were based on data drawn from power grids in two different nations, compare and contrast the nations' strategy for power distribution on this level.***

# %% [markdown]
# We make the hypothesis that these networks were based on data drawn from power grids in two different nations. We can thus analyze the different strategies for each country.
#
# **Clustering coefficient:**
#
# The **network 2 has a bigger clustering coefficient than the network 3**. We can thus deduce a difference in the strategy for power distribution. In fact, an higher overall clustering coefficient means that we become closer to a small world network. The more important things are that the higher the coefficient clustering is, the higher the number of the cycle in the graph is.
#
# A small-world network is a type of mathematical graph in which most nodes are not neighbors of one another, but the neighbors of any given node are likely to be neighbors of each other and most nodes can be reached from every other node by a small number of hops or steps. This is the opposite when the clustering coefficient is lower. You also need to have typical distance L between two randomly chosen nodes (the number of steps required) grows proportionally to the logarithm of the number of nodes N in the network to have small world network.
#
# Thus, we can see that **the strategy of the nation of network 2 is to try to link more nodes and try to allow a node to be reached from every other node. On the contrary, the nation of network 3 wants to create a more sequential network where paths between node are more unique.**
#
#
# ** Distribution:**
#
# We defined the clustering coefficient of a node in a graph as the proportion of that node's neighbors that are connected and proceeded to define the clustering coefficient as the corresponding measure applied to the whole network. In some case, however, we may be interested in the distribution of the clustering coefficient over the nodes in the network. For instance, a network could have some very clustered parts, and some less clustered parts, while another network could have many nodes with a similar, average clustering coefficient. Thus, we may want to consider the distribution of the clustering coefficient. This distribution can be plotted as a cumulated plot but we did not do that.
#
# In our case, the **distribution of the clustering coefficient of the network 3 is tighter in comparison to network 2 in term of range**.  The range of the distribution of the network 2 is from 0 to 0.8 in opposition to network 3 which is more half of it. The **center of the distributions is thus not the same**.
#
# We can thus imagine that the network 3 is made of **some small and less dense independent clusters** (due to the high number of cluster coefficient between 0 and 0.4 with a peek at 0.2). In opposition, the **network 2 seems to have more different clusters with different size and density of connections**. The conclusion stays similar: for the **network 3, the strategy is to more compartmentalized the power grid node in opposition to the network 2 where the goal is more to allow a node to be reached from every other node.

# %% [markdown]
# ### 3.9
# ***If I told you that these networks were "friendship networks" drawn from two different schools, how do the patterns of friendship differ between the two schools? What kind of forces could be in play at the two different schools that may explain the differences? Feel free to think creatively, but also respect the bounds of logic.***

# %% [markdown]
# **How do the patterns of friendship differ:**
#
# We reuse the conclusion drawn in the questions above :
#
#    * Cluster coefficient: Network 2 has a bigger overall clustering coefficient and average clustering coefficient than the network 3. A higher overall clustering coefficient means that we become closer to a small world network and more importantly, that there is much more clear cluster in the network.
#    * Distribution: The network 3 is made of some small and less dense independent clusters (due to the high number of cluster coefficient between 0 and 0.4 with a peek at 0.2). In opposition, the network 2 seems to have more different clusters with different size and denser.
#
# In conclusion, we see a difference between the network of the two school : **the one of the network 2 seems more linked to all the members and thus it seems that students in this school know the others better** than in school of network 3. **They seems to form more a huge linked group, like a small word**. In opposition, the school of **network 3 seems to be more compartmentalized** and thus seems to be made more by small less dense clusters. It seems to be more like several small groups living in the same place but without knowing everyone.
#
# **What kind of forces could be in play at the two different schools:**
#
#
# So the network 2 is more clustered than the network 3. The overall/average clustering coefficient is a measure of how and how much individuals in the network are they connected. It's a kind of frequency of the link given a subset of nodes. In a social network, it measures how many of your friends know your own friends. It shows how they interact together. Clustering may be due to physical constraints, like for example with the language barrier. If you have a class that is speaking Italian and another one that is speaking French, this to class will tend to form an independent cluster. Moreover, in a school perhaps social activity like a football match or cultural activity are organized out of the course tie allowing the students to know more each other and thus to know more the friends of your friends.

# %% [markdown]
# ----
# ## Problem 4
# 17 points.
#
# In the second lecture we discussed shortest paths, network diameter and average shortest path lengths. In this problem we explore those measures for our networks.
#
# 1. For each of the three networks find the Giant Connected Component (GCC). For the rest of this problem we will analyze only the GCCs, so please store them as G_1_GCC, G_2_GCC and G_3_GCC. [<span style="color:red">Technical</span>] [1]
# 2. For each of the three GCCs, calculate the distance matrix ($d_{i,j}$). _hint_: use a built in function [<span style="color:red">Technical</span>] [1]
# 3. __Directly from the distance matricies calculted in the previous step__, extract the diameter of each GCC. [<span style="color:red">Technical</span>] [1]
# 4. Again __from those distance matricies__, calculate the average shortest path length of each GCC. [<span style="color:red">Technical</span>] [1]
# 5. Create a table similar to the one for Question 3.6 summarizing the diameter and average shortest path for each of the three GCCs. How do these measures compare for each network. [<span style="color:blue">Analytical</span>] [1]
# 6. Considering all of the measures and distributions you have calculated for these networks in the previous problems (_i.e._ degree distribution and clusterings) which seem to infludence diameter and average shortest path length the most. [<span style="color:blue">Analytical</span>] [2]
# 7. If I told you that these networks were the undirected version of an air transport network (nodes are cities/airports, a link indicates at least one flight between them) for three different countries, what may you infer about the organization of each country, regulations on air travel, _etc_. Feel free to think creatively, but also respect the bounds of logic. [<span style="color:blue">Analytical</span>] [2]
# 8. In each the GCCs of G_2 and G_3 find:
#     * The 10 nodes with the _highest_ average shortest path length to each other node in the network.
#     * The 10 nodes with the _lowest_ average shortest path length to each other node in the network.
#     * The 5 nodes with the _highest_ degree.
#     * All of nodes with the _lowest_ degree. [<span style="color:red">Technical</span>] [3]
# 9. For each of the sets of nodes identified in the previous question, make a network in which those nodes have been deleted from the GCC. This should result in a total of __8 new networks__. [<span style="color:red">Technical</span>] [2]
# 10. For each of the 8 networks generated in the previous step, calculate the diameter and average shortest path length. __Do not__ do this by calculating the distance matrix, but rather, use networkx's built in functions for diameter and average shortest path length. [<span style="color:red">Technical</span>] [1]
# 11. When you delete each set of nodes, how do the diameter and average shortest path length change relative to the full GCC? Which kind of deletions increase the diameter/average shortest path length the most. Which increase it the most. Why? [<span style="color:blue">Analytical</span>] [2]

# %% [markdown]
# #### Problem 4 Marks
#
# 4.1) 1/1
#
# 4.2) 1/1
#
# 4.3) 1/1
#
# 4.4) 1/1
#
# 4.5) 1/1
#
# 4.6) 2/2
#
# 4.7) 2/2
#
# 4.8) 3/3
#
# 4.9) 2/2
#
# 4.10) 1/1
#
# 4.11) 2/2
#
# Total: 17/17

# %%
Problem4Score = 17
Scores.append(Problem4Score)

# %% [markdown]
# ----

# %% [markdown]
# ### 4.1
# ***For each of the three networks find the Giant Connected Component (GCC). For the rest of this problem we will analyze only the GCCs, so please store them as G_1_GCC, G_2_GCC and G_3_GCC.***

# %%
# Find the giant connected component for each graph
G_1_GCC = max(nx.connected_component_subgraphs(G_1), key=len)
G_2_GCC = max(nx.connected_component_subgraphs(G_2), key=len)
G_3_GCC = max(nx.connected_component_subgraphs(G_3), key=len)
# Draw G_1_GCC
plt.figure(figsize=(14,7))
nx.draw_networkx(G_1_GCC, pos=nx.spring_layout(G_1_GCC), with_labels = False, node_size = 30)
plt.title('G_1 Giant Connected Component (GCC) graph representation :')
# Draw G_2_GCC
plt.figure(figsize=(14,7))
nx.draw_networkx(G_2_GCC, pos=nx.spring_layout(G_2_GCC), with_labels = False, node_size = 30)
plt.title('G_2 Giant Connected Component (GCC) graph representation :')
# Draw G_3_GCC
plt.figure(figsize=(14,7))
nx.draw_networkx(G_3_GCC, pos=nx.spring_layout(G_3_GCC), with_labels = False, node_size = 30)
plt.title('G_3 Giant Connected Component (GCC) graph representation :')
plt.show()

# %% [markdown]
# ### 4.2
#
# ***For each of the three GCCs, calculate the distance matrix ( di,jdi,j ). hint: use a built in function ***

# %%
# Find the shortest path for each node in the graph next to the floyd warchall method and output it in a numpy array
G_1_GCC_shortestpath = nx.floyd_warshall_numpy(G_1_GCC)
G_2_GCC_shortestpath = nx.floyd_warshall_numpy(G_2_GCC)
G_3_GCC_shortestpath = nx.floyd_warshall_numpy(G_3_GCC)

# %% [markdown]
# ### 4.3
#
# ***Directly from the distance matricies calculted in the previous step, extract the diameter of each GCC. ***
#
# We can do that because we know that a network’s diameter is the longest shortest path among all nodes in a network. So we use the max function from numpy.

# %%
# A network’s diameter is the longest shortest path among all nodes in a network.
G_1_GCC_diameter = np.max(G_1_GCC_shortestpath)
G_2_GCC_diameter = np.max(G_2_GCC_shortestpath)
G_3_GCC_diameter = np.max(G_3_GCC_shortestpath)
print('From distance matrix : \n  Diameter of G_1_GCC : ', G_1_GCC_diameter, '\n  Diameter of G_2_GCC : ', G_2_GCC_diameter, '\n  Diameter of G_3_GCC : ', G_3_GCC_diameter)
# we can use to check our result the build in function of networkx
print('\nBuild in function : \n  Diameter of G_1_GCC : ', nx.diameter(G_1_GCC), '\n  Diameter of G_2_GCC : ', nx.diameter(G_2_GCC), '\n  Diameter of G_3_GCC : ', nx.diameter(G_3_GCC))
# Out:
# From distance matrix :
#   Diameter of G_1_GCC :  11.0
#   Diameter of G_2_GCC :  5.0
#   Diameter of G_3_GCC :  5.0
#
# Build in function :
#   Diameter of G_1_GCC :  11
#   Diameter of G_2_GCC :  5
#   Diameter of G_3_GCC :  5

# %% [markdown]
# ### 4.4
#
# ***Again from those distance matricies, calculate the average shortest path length of each GCC. ***

# %%
# The average shortest path length is the mean of the distance matrix
G_1_GCC_average_shortest_path_length = np.mean(G_1_GCC_shortestpath)
G_2_GCC_average_shortest_path_length = np.mean(G_2_GCC_shortestpath)
G_3_GCC_average_shortest_path_length = np.mean(G_3_GCC_shortestpath)
print('From distance matrix : \n  Average shortest path length of G_1_GCC : ', G_1_GCC_average_shortest_path_length, '\n  Average shortest path length of G_2_GCC : ', G_2_GCC_average_shortest_path_length, '\n  Average shortest path length of G_3_GCC : ', G_3_GCC_average_shortest_path_length)
# We check with the build in function
print('\nBuild in function :  \n  Average shortest path length of G_1_GCC : ', nx.average_shortest_path_length(G_1_GCC), '\n  Average shortest path length of G_2_GCC : ', nx.average_shortest_path_length(G_2_GCC), '\n  Average shortest path length of G_3_GCC : ', nx.average_shortest_path_length(G_3_GCC))
# The difference in the result comes from the technic used to calculate the shortest path but the results stay similar
# Out:
# From distance matrix :
#   Average shortest path length of G_1_GCC :  4.547473069366982
#   Average shortest path length of G_2_GCC :  2.5015160581684412
#   Average shortest path length of G_3_GCC :  2.4091067907357804
#
# Build in function :
#   Average shortest path length of G_1_GCC :  4.557026584218593
#   Average shortest path length of G_2_GCC :  2.506539182783237
#   Average shortest path length of G_3_GCC :  2.413944354572599

# %% [markdown]
# ### 4.5

# %% [markdown]
# **Create a table similar to the one for Question 3.6 summarizing the diameter and average shortest path for each of the three GCCs. How do these measures compare for each network.**
#
# |         |   Diameter    | Average shortest path |
# |---------| :-----------: |:-------------:|
# |Network GCC 1|       11      |     4.55      |
# |Network GCC 2|       5       |     2.5       |
# |Network GCC 3|       5       |     2.41      |

# %% [markdown]
# **Diameter**: The diameter of the GCC 1 is higher than the one for GCC2 and GCC 3. In fact, this diameter is more than twice than the two other networks. Moreover, GCC2 and GCC3 have exactly the same diameter: 5.
#
# **Average shortest path**: For this statistic, the same observation as the one for diameter can be applied. In fact, the average shortest path of the network GCC 1 is higher than the one of GCC 2 and GCC 3. This time, the value of this statistic is a little bit less than twice the value of the two other GCC. In addition, the average shortest path is nearly the same for GCC2 and GCC3.
#
# See questions 4.7 for more details.

# %% [markdown]
# ### 4.6
#
# ***Considering all of the measures and distributions you have calculated for these networks in the previous problems (i.e. degree distribution and clusterings) which seem to infludence diameter and average shortest path length the most.***

# %% [markdown]
# As we can see for **network 2 and 3 the diameter and the average shortest path seems to be the same**. Moreover, it has a s**maller diameter and a smaller average shortest path compared to network 1**.
#
# In another hand, the degree distribution was identical for network 2 and 3. Compare to network, the average degree is smaller in network 1 than in 2 and 3 imply a shift to the right in the degree distribution (for network 2 and 3). Thus, we can conclude thanks to these experimental observations that the degree distribution can be the cause of the difference between network 1 and network 2 and 3 in term of diameter and average shortest path. **An smaller degree distribution in our case seems to induce and higher Diameter and average Shortest path.**
#
# Then, the clustering coefficient was compared between network 2 and 3. In fact network 2 was generally more clustered than network 3. **Thus we can conclude that a higher clustering coefficient has no effect on diameter but has a really small effect on the average shortest path.** This effect is so small on our **experimental observation that this concept cannot be reliable.**
#
# Thus, **the degree distribution influence diameter and average shortest path length the most.**

# %% [markdown]
# ### 4.7
#
# ***If I told you that these networks were the undirected version of an air transport network (nodes are cities/airports, a link indicates at least one flight between them) for three different countries, what may you infer about the organization of each country, regulations on air travel, etc. Feel free to think creatively, but also respect the bounds of logic.***

# %% [markdown]
# By looking at the average shortest path and diameter statistics, the first thing we see is that we can consider that GCC of network 2 and GCC of network 3 similar. Thus we will compare these two graphs with similar statistics to the network GCC 1.
#
# **Diameter** :
#
# The GCC of network 1 has a diameter of 11 nodes. **This diameter is more than twice diameter of GCC 2 and 3 (for whom the diameter is 5).** A network’s diameter is the longest shortest path among all nodes in a network. Diameter can be a coarse measure, however, as it deals with only a single (extreme) pair of nodes.
#
# **Average shortest path** :
#
# A network’s average path length, or even path length distribution, offers a more nuanced view of distances within the network compared to the diameter.**We are in the same case as for the diameter.** In fact, the GCC of network 1 has an average shortest path of 4.55 nodes. This diameter is a little bit less than twice the average shortest path of GCC 2 and 3 (for whom the average shortest path is approximately 2.5).
#
# **Interpretation** :
#
#
# We make the hypothesis that nodes are cities/airports and link indicates at least one flight.
#
# Thus the difference in diameter statistic could mean that the GCC network 1 less densely link. It means that the network should be less connected and thus that a passenger should take several flights to go where he wants. **If he chooses the wrong destination, he had to take 11 flights in the worst case. In comparison, for network 2 and 3, the maximum number of flight would be 5.** This concept can be applied to all the graph thanks to the average shortest path statistic.
#
# As the diameter is the longest shortest path, it could also mean that there are more airports in the network with the smallest diameter. In the network with a small diameter and small average shortest path, several paths can allow you to go in the same destination. **It's easy to go everywhere you want in less number of flights than for network 1**. The average shortest path is showing the same thing for the all graph. **The network 1 is more sequential and less accessible for a traveler. This gives an indication of all the network tendency**. In fact to go to a place you need to take more flight in network 1 than in network 2 and 3.
#
# This **network 1 is a more restrictive network**, where you need to spend more step to go where you want. This can be **due to regulations on air travel between when you change of countries for example.** In opposition, network 2 and 3 seems to have fewer regulations and can be for example **a network inside a country where border check-up are not needed.**

# %% [markdown]
# ### 4.8
#
# ***In each the GCCs of G_2 and G_3 find:***
#    * The 10 nodes with the highest average shortest path length to each other node in the network.
#    * The 10 nodes with the lowest average shortest path length to each other node in the network.
#    * The 5 nodes with the highest degree.
#    * All of nodes with the lowest degree.

# %%
def n_function_average_shortest(G, function = 'max', n = 10):
    '''
    This function allows to find the n nodes with the highest or lowest average shortest path length to each other node in the network
    ARGS :
        - G : networkx graph object.
        - function : String which should be max or min defining if we take the highest or the lowest nodes.
        - n : Interger defining how many highest or lowest nodes we select.
    RETURN :
        - n_output : List corresponding to the id of the n highest or lowest node in the G network.
    '''
    n_output = []
    G_GCC_shortestpath = nx.floyd_warshall_numpy(G)
    df_G_GCC = pd.DataFrame(np.mean(G_GCC_shortestpath, axis = 1), columns = {'Shortest_path_average'})
    if function == 'min':
        n_output = df_G_GCC.sort_values(by = 'Shortest_path_average')[:n]
    elif function == 'max':
        n_output = df_G_GCC.sort_values(by = 'Shortest_path_average')[-n:]
    return n_output

# %%
def min_and_max(G_GCC, n = 10):
    '''
    This function allows the finding of the n highest or lowest node thanks to the n_function_average_shortest() functions and put it in a good format for printing
    ARGS :
        - G_GCC : networkx graph object corresponding to the Giant Connected Component of the graph of interest.
        - n : Interger defining how many highest or lowest nodes we select.
    RETURN : 
        - node_max : Dataframe containing the id of the node and the shortest path average of the n highest nodes.
        - node_min : Dataframe containing the id of the node and the shortest path average of the n lowest nodes.
    '''
    node_min = n_function_average_shortest(G_GCC, function = 'min', n = n)
    node_max = n_function_average_shortest(G_GCC, function = 'max', n = n)
    node_min = node_min.reset_index().rename(columns = {'index':'Node'})
    node_max = node_max.reset_index().rename(columns = {'index':'Node'})
    return node_max, node_min

# %%
def n_highest_lowest_degree(G, function = 'highest', n = 5):
    '''
    This functions allows us to find the 5 nodes with the highest degree, and all of nodes with the lowest degree.
    ARGS :
        - G : networkx graph object.
        - function : String that should be 'highest' or 'lowest' defining if we want to return 5 nodes with the highest degree or all of nodes with the lowest degree
        - n : Interger defining how many highest nodes we select.
    RETURN : 
        - output : Dataframe containing the id of the node and the shortest path average of the n highest nodes, or all the lowest nodes.
    '''
    output = []
    df_degree = pd.DataFrame.from_dict(nx.degree(G)).rename(columns = {0 : 'Node', 1 : 'Degree'}).sort_values(by = 'Degree')
    if function == 'highest':
        output = df_degree[-n:].reset_index(drop=True)
    elif function == 'lowest':
        output = df_degree[df_degree.Degree == df_degree.Degree.min()].reset_index(drop=True)
    return output

# %%
def degree_and_shortest_path_minima(n = 10):
    '''
    This functions allows the computation of the asked information for both graph and format it in a dictionnary.
    ARG :
        - n : Interger defining how many highest or lowest nodes we select for the n_highest_lowest_degree() function.
    RETURN :
        - output : Dictionary containing all the dataframe with the informations about selected nodes.
    '''
    output = {'10_highest_average_shortest_path_length_G_2' : [min_and_max(G_2_GCC, n = n)[0], G_2_GCC.copy()],
              '10_lowest_average_shortest_path_length_G_2' : [min_and_max(G_2_GCC, n = n)[1], G_2_GCC.copy()],
              '5_highest_degree_G_2' : [n_highest_lowest_degree(G_2_GCC, function = 'highest', n = 5), G_2_GCC.copy()],
              'all_lowest_degree_G_2' : [n_highest_lowest_degree(G_2_GCC, function = 'lowest', n = 5), G_2_GCC.copy()],
              '10_highest_average_shortest_path_length_G_3' : [min_and_max(G_3_GCC, n = n)[0], G_3_GCC.copy()],
              '10_lowest_average_shortest_path_length_G_3' : [min_and_max(G_3_GCC, n = n)[1], G_3_GCC.copy()],
              '5_highest_degree_G_3' : [n_highest_lowest_degree(G_3_GCC, function = 'highest', n = 5), G_3_GCC.copy()],
              'all_lowest_degree_G_3' : [n_highest_lowest_degree(G_3_GCC, function = 'lowest', n = 5), G_3_GCC.copy()],
             }
    return output

# %%
def print_output():
    '''
    This functions allows to compute the final dictionnary containing all wanted informations and to print it.
    RETURN :
        - output : Dictionary containing all the dataframe with the informations about selected nodes.
    '''
    output = degree_and_shortest_path_minima()
    for key in output.keys():
        print('\n', key, '\n', output[key][0])
    return output

# %%
import pandas as pd
output = print_output()
# Out:
#  10_lowest_average_shortest_path_length_G_3
#     Node  Shortest_path_average
# 0   346               1.727455
# 1   202               1.787575
# 2   385               1.865731
# 3    34               1.895792
# 4   458               1.921844
# 5   473               1.935872
# 6   374               1.941884
# 7   269               1.949900
# 8    66               1.949900
# 9   237               1.951904
#
#  all_lowest_degree_G_2
#     Node  Degree
# 0   138       1
# 1    74       1
# 2    52       1
# 3    43       1
#
#  5_highest_degree_G_2
#     Node  Degree
# 0    56      78
# 1    35      97
# 2   387     103
# 3   203     136
# 4   348     163
#
#  10_highest_average_shortest_path_length_G_2
#     Node  Shortest_path_average
# 0   182               3.186373
# 1    42               3.202405
# 2    73               3.208417
# 3   284               3.212425
# 4    80               3.218437
# 5   178               3.224449
# 6    89               3.360721
# ...

# %% [markdown]
# ### 4.9
# ***For each of the sets of nodes identified in the previous question, make a network in which those nodes have been deleted from the GCC. This should result in a total of 8 new networks.***

# %%
# In this cell, we deleted the selected cells and we print the new network
i = 0
for key in output.keys():
    for i in output[key][0]['Node'].values:
        output[key][1].remove_node(i)
    plt.figure(figsize=(14,7))
    nx.draw_networkx(output[key][1], pos=nx.spring_layout(output[key][1]), with_labels = False, node_size = 30)
    plt.title('Graph of the Giant Connected component by supressing {key}'.format(key=key))

# %% [markdown]
# ### 4.10
# ***For each of the 8 networks generated in the previous step, calculate the diameter and average shortest path length. Do not do this by calculating the distance matrix, but rather, use networkx's built in functions for diameter and average shortest path length. ***

# %%
# We store in the dictionary the wanted informations : diameter and shortest path
for key in output.keys():
    output[key].append(nx.diameter(output[key][1]))
    output[key].append(nx.average_shortest_path_length(output[key][1]))

# %%
# We print the calculated informations
print('G_2 :\n')
for key in output.keys():
    if key == '10_highest_average_shortest_path_length_G_3':
        print('\nG_3 :\n')
    print('{} removed : Diameter = {} | Shortest path lenght = {}'.format(key, output[key][2], output[key][3]))
# Out:
# G_2 :
#
# 10_lowest_average_shortest_path_length_G_3 removed : Diameter = 5 | Shortest path lenght = 2.416750477723021
# all_lowest_degree_G_2 removed : Diameter = 5 | Shortest path lenght = 2.4915306915306914
# 5_highest_degree_G_2 removed : Diameter = 6 | Shortest path lenght = 2.7158272495093247
# 10_highest_average_shortest_path_length_G_2 removed : Diameter = 5 | Shortest path lenght = 2.512739280565892
#
# G_3 :
#
# 10_highest_average_shortest_path_length_G_3 removed : Diameter = 5 | Shortest path lenght = 2.413456703208287
# all_lowest_degree_G_3 removed : Diameter = 4 | Shortest path lenght = 2.399051241156504
# 10_lowest_average_shortest_path_length_G_2 removed : Diameter = 5 | Shortest path lenght = 2.5143316906366286
# 5_highest_degree_G_3 removed : Diameter = 6 | Shortest path lenght = 2.5649292524492697

# %% [markdown]
# ### 4.11
# ***When you delete each set of nodes, how do the diameter and average shortest path length change relative to the full GCC? Which kind of deletions increase the diameter/average shortest path length the most. Which increase it the most. Why?***
#
# Just as a reminder :
#
#
# |         |   Diameter    | Average shortest path |
# |---------| :-----------: |:-------------:|
# |Network GCC 1|       11      |     4.55      |
# |Network GCC 2|       5       |     2.5       |
# |Network GCC 3|       5       |     2.41      |

# %% [markdown]
# **How do the diameter and average shortest path length change relative to the full GCC:**
#
# It depends on which set of nodes we deleted from the graph :
#    * G_2 diameter:
#       * When we deleted 10_highest_average_shortest_path_length_G_2, 10_lowest_average_shortest_path_length_G_2 and all_lowest_degree_G_2 the diameter stay the same.
#       * When we deleted 5_highest_degree_G_2, the diameter increase by one compare to the full GCC.
#    * G_2 average shortest path:
#       * When we deleted 10_highest_average_shortest_path_length_G_2, 10_highest_average_shortest_path_length_G_3  the average shortest path increase by 0.01 and 0.02 approximately.
#       * When we deleted 5_highest_degree_G_2, the average shortest path increase by 0.21 compare to the full GCC.
#       * When we deleted all_lowest_degree_G_2, the average shortest path decrease by 0.01 compare to the full GCC.
#
#    * G_3 diameter:
#       * When we deleted 10_highest_average_shortest_path_length_G_3, 10_lowest_average_shortest_path_length_G_3  the diameter stay the same.
#       * When we deleted 5_highest_degree_G_3, the diameter increase by one compare to the full GCC.
#       * When we deleted all_lowest_degree_G_3, the diameter decrease by one compare to the full GCC.
#    * G_3 average shortest path:
#       * When we deleted 10_highest_average_shortest_path_length_G_3, 10_lowest_average_shortest_path_length_G_3  the average shortest path stay the same approximately.
#       * When we deleted 5_highest_degree_G_3, the average shortest path increase by 0.15 compare to the full GCC.
#       * When we deleted all_lowest_degree_G_3, the average shortest path decrease by 0.01 compare to the full GCC.
#
# **Which kind of deletions increase the diameter/average shortest path length the most:**
#
# As we saw just before, deleted 5_highest_degree nodes increase diameter. Moreover, 10_highest_average_shortest_path_length nodes, 10_highest_average_shortest_path_length nodes and 5_highest_degree nodes increase the shortest path length.
# The one which increases most the shortest path length is deleted 5_highest_degree nodes. **Thus deleted 5_highest_degree nodes increase the diameter/average shortest path length the most**.
#
# **Which increase it the most:**
#
# As we previously said, deleted 5_highest_degree nodes increase the diameter/average shortest path length the most.
#
# **Why?**
#
# It makes sense that deleted the 5 highest degree nodes increase the diameter and the average shortest path length as these nodes are responsible for a high percentage of the links in all network. In fact, by definition, these nodes are the more connected nodes and thus are the more important one considering these two metrics.
#
#
# They are increasing these measures the most because they are more important than the highest average shortest path length because the highest average shortest path length nodes are not doing the links inside the network by definition. The shortest path did not give us the more important node in term of diameter. Moreover, as the average shortest path is a mean compared to the diameter that is a maximum, by definition a maximum is more sensitive to extreme values compared to the mean which is more robust. Thus suppressing the one with a higher degree has more importance.

# %% [markdown]
# ----
#
# ----

# %%
FinalGrade = sum(Scores)
print("Final grade is {} out of 50".format(FinalGrade))
# Out:
# Final grade is 50 out of 50
